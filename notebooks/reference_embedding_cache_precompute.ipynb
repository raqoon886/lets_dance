# %% [markdown]
# # Reference Embedding Precompute
#
# 이 노트북은 이미 학습된 `scratch` / `embedding` TFLite encoder를 각 `reference.npy`에 적용해서, 서비스 런타임에서 재사용할 reference embedding cache를 만든다.
#
# 핵심 아이디어:
#
# ```text
# reference.npy의 30프레임 window
# → TFLite encoder
# → reference embedding vector
# → data/cache/reference_embeddings/*.npz 저장
# ```
#
# 서비스 중에는 유저 window만 실시간 TFLite 추론하고, reference 쪽은 이 cache에서 벡터를 꺼내 cosine similarity만 계산하도록 최적화할 수 있다.

# %% [markdown]
# ## 0. 환경 설정

# %%
from pathlib import Path
import json
import subprocess
import sys

import numpy as np
import matplotlib.pyplot as plt

start = Path.cwd().resolve()
candidates = [start, *start.parents]
for base in [start, *start.parents]:
    candidates.extend([
        base / 'boot_env' / 'pjt_main',
        base / 'pjt_main',
    ])

PROJECT_ROOT = None
for candidate in candidates:
    if (candidate / 'scripts' / 'precompute_reference_embeddings.py').exists():
        PROJECT_ROOT = candidate
        break
if PROJECT_ROOT is None:
    raise RuntimeError('pjt_main project root를 찾지 못했습니다.')

sys.path.insert(0, str(PROJECT_ROOT))
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

SCRIPT = PROJECT_ROOT / 'scripts' / 'precompute_reference_embeddings.py'
DATA_DIR = PROJECT_ROOT / 'data' / 'reference_dances'
SCRATCH_MODEL_DIR = PROJECT_ROOT / 'data' / 'models' / 'scratch'
EMBEDDING_MODEL_DIR = PROJECT_ROOT / 'data' / 'models' / 'embedding'
CACHE_DIR = PROJECT_ROOT / 'data' / 'cache' / 'reference_embeddings'
CACHE_DIR.mkdir(parents=True, exist_ok=True)

print('PROJECT_ROOT =', PROJECT_ROOT)
print('SCRIPT =', SCRIPT)
print('CACHE_DIR =', CACHE_DIR)
print('PYTHON =', sys.executable)
# Out:
# PROJECT_ROOT = /workspace/users/yijin/boot_env/pjt
# SCRIPT = /workspace/users/yijin/boot_env/pjt/scripts/precompute_reference_embeddings.py
# CACHE_DIR = /workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings
# PYTHON = /workspace/users/yijin/boot_env/.venv/bin/python

# %% [markdown]
# ## 1. 현재 모델과 reference dance 확인
#
# `reference.npy`가 있는 dance만 cache 생성 대상이다. `metadata.json`에 video가 있더라도, embedding cache는 video가 아니라 `reference.npy`에서 만든다.

# %% [markdown]
# ## 1. 현재 모델과 reference dance 확인
#
# `reference.npy`가 있는 dance만 cache 생성 대상이다. `metadata.json`에 video가 있더라도, embedding cache는 video가 아니라 `reference.npy`에서 만든다.

# %%
models = []
for kind, model_dir in [('scratch', SCRATCH_MODEL_DIR), ('embedding', EMBEDDING_MODEL_DIR)]:
    for model_path in sorted(model_dir.glob('*.tflite')):
        meta_path = model_dir / f'{model_path.stem}_meta.json'
        meta = json.loads(meta_path.read_text(encoding='utf-8')) if meta_path.exists() else {}
        models.append({
            'kind': kind,
            'name': model_path.stem,
            'path': model_path,
            'size_kib': model_path.stat().st_size / 1024,
            'input_shape': meta.get('input_shape'),
            'output_shape': meta.get('output_shape'),
        })

print('models')
for m in models:
    print(f" - {m['kind']:9s} {m['name']:32s} {m['size_kib']:8.1f} KiB input={m['input_shape']} output={m['output_shape']}")

dances = []
for ref_path in sorted(DATA_DIR.glob('*/reference.npy')):
    arr = np.load(ref_path, allow_pickle=True)
    dances.append({'name': ref_path.parent.name, 'path': ref_path, 'shape': arr.shape})

print()
print('dances')
for d in dances:
    print(f" - {d['name']:16s} shape={d['shape']}")
# Out:
# models
#  - scratch   scratch_gcn_base_infonce_e64_final    188.4 KiB input=[1, 30, 12, 2] output=[1, 64]
#  - scratch   scratch_gcn_base_triplet_e64_final    188.4 KiB input=[1, 30, 12, 2] output=[1, 64]
#  - scratch   scratch_gcn_small_infonce_e32_final     47.7 KiB input=[1, 30, 12, 2] output=[1, 32]
#  - scratch   scratch_gcn_small_triplet_e32_final     47.7 KiB input=[1, 30, 12, 2] output=[1, 32]
#  - scratch   scratch_mlp_base_infonce_e64_final     40.5 KiB input=[1, 30, 12, 2] output=[1, 64]
#  - scratch   scratch_mlp_base_triplet_e64_final     40.5 KiB input=[1, 30, 12, 2] output=[1, 64]
#  - scratch   scratch_mlp_small_infonce_e32_final     15.0 KiB input=[1, 30, 12, 2] output=[1, 32]
#  - scratch   scratch_mlp_small_triplet_e32_final     15.0 KiB input=[1, 30, 12, 2] output=[1, 32]
#  - scratch   scratch_tcn_base_infonce_e64_final    126.7 KiB input=[1, 30, 12, 2] output=[1, 64]
#  - scratch   scratch_tcn_base_triplet_e64_final    126.7 KiB input=[1, 30, 12, 2] output=[1, 64]
#  - scratch   scratch_tcn_small_infonce_e32_final     34.1 KiB input=[1, 30, 12, 2] output=[1, 32]
#  - scratch   scratch_tcn_small_triplet_e32_final     34.1 KiB input=[1, 30, 12, 2] output=[1, 32]
#  - embedding finetune_gcn_base_infonce_e64_final    188.4 KiB input=[1, 30, 12, 2] output=[1, 64]
#  - embedding finetune_gcn_base_triplet_e64_final    188.4 KiB input=[1, 30, 12, 2] output=[1, 64]
#  - embedding finetune_gcn_small_infonce_e32_final     47.7 KiB input=[1, 30, 12, 2] output=[1, 32]
#  - embedding finetune_gcn_small_triplet_e32_final     47.7 KiB input=[1, 30, 12, 2] output=[1, 32]
#  - embedding finetune_mlp_base_infonce_e64_final     40.5 KiB input=[1, 30, 12, 2] output=[1, 64]
#  - embedding finetune_mlp_base_triplet_e64_final     40.5 KiB input=[1, 30, 12, 2] output=[1, 64]
#  - embedding finetune_mlp_small_infonce_e32_final     15.0 KiB input=[1, 30, 12, 2] output=[1, 32]
#  - embedding finetune_mlp_small_triplet_e32_final     15.0 KiB input=[1, 30, 12, 2] output=[1, 32]
#  - embedding finetune_tcn_base_infonce_e64_final    126.7 KiB input=[1, 30, 12, 2] output=[1, 64]
#  - embedding finetune_tcn_base_triplet_e64_final    126.7 KiB input=[1, 30, 12, 2] output=[1, 64]
#  - embedding finetune_tcn_small_infonce_e32_final     34.1 KiB input=[1, 30, 12, 2] output=[1, 32]
#  - embedding finetune_tcn_small_triplet_e32_final     34.1 KiB input=[1, 30, 12, 2] output=[1, 32]
#
# dances
#  - 404_dance        shape=(568, 33, 3)
#  - basic_movement   shape=(476, 33, 3)
#  - beginner_wave    shape=(679, 33, 3)
#  - cheerup_dance    shape=(724, 33, 4)
#  - freestyle_free   shape=(3600, 33, 4)
#  - hiphop_move      shape=(792, 33, 4)
#  - kpop_basic       shape=(7164, 33, 3)
#  - rasputin         shape=(3147, 33, 3)
#  - shuffle_dance    shape=(1538, 33, 3)
#  - smoke            shape=(1, 33, 4)

# %% [markdown]
# ## 2. Dry-run으로 생성 계획 확인
#
# 아래 셀은 실제 TFLite 추론을 하지 않고, 어떤 cache 파일이 만들어질지만 확인한다.
#
# `cache_stride=1`은 모든 end frame에 대해 embedding을 저장한다. 가장 유연하고 추천되는 기본값이다. 빠른 테스트만 하고 싶으면 `30`처럼 크게 둔다.

# %%
DRY_RUN_MODEL_KIND = 'all'       # 'scratch', 'embedding', 'all'
DRY_RUN_MODEL_NAMES = []         # 예: ['embedding_tcn_e64_triplet']; 빈 리스트면 전체
DRY_RUN_DANCE_NAMES = []         # 예: ['cheerup_dance']; 빈 리스트면 reference.npy가 있는 전체
DRY_RUN_CACHE_STRIDE = 30        # 계획 확인은 출력이 짧도록 30 사용

cmd = [
    sys.executable, str(SCRIPT),
    '--model-kind', DRY_RUN_MODEL_KIND,
    '--data-dir', str(DATA_DIR),
    '--scratch-model-dir', str(SCRATCH_MODEL_DIR),
    '--embedding-model-dir', str(EMBEDDING_MODEL_DIR),
    '--output-dir', str(CACHE_DIR),
    '--cache-stride', str(DRY_RUN_CACHE_STRIDE),
    '--dry-run',
]
for name in DRY_RUN_MODEL_NAMES:
    cmd += ['--model-name', name]
for name in DRY_RUN_DANCE_NAMES:
    cmd += ['--dance-name', name]

print(' '.join(cmd))
subprocess.check_call(cmd, cwd=PROJECT_ROOT)
# Out:
# /workspace/users/yijin/boot_env/.venv/bin/python /workspace/users/yijin/boot_env/pjt/scripts/precompute_reference_embeddings.py --model-kind all --data-dir /workspace/users/yijin/boot_env/pjt/data/reference_dances --scratch-model-dir /workspace/users/yijin/boot_env/pjt/data/models/scratch --embedding-model-dir /workspace/users/yijin/boot_env/pjt/data/models/embedding --output-dir /workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings --cache-stride 30 --dry-run
# PROJECT_ROOT = /workspace/users/yijin/boot_env/pjt
# models = 24
#  - scratch::scratch_gcn_base_infonce_e64_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_gcn_base_triplet_e64_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_gcn_small_infonce_e32_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_gcn_small_triplet_e32_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_mlp_base_infonce_e64_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_mlp_base_triplet_e64_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_mlp_small_infonce_e32_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_mlp_small_triplet_e32_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_tcn_base_infonce_e64_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_tcn_base_triplet_e64_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_tcn_small_infonce_e32_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_tcn_small_triplet_e32_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_gcn_base_infonce_e64_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_gcn_base_triplet_e64_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_gcn_small_infonce_e32_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_gcn_small_triplet_e32_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_mlp_base_infonce_e64_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_mlp_base_triplet_e64_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_mlp_small_infonce_e32_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_mlp_small_triplet_e32_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_tcn_base_infonce_e64_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_tcn_base_triplet_e64_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_tcn_small_infonce_e32_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_tcn_small_triplet_e32_final seq=30 fd=2 layout=BTJC
# dances = 10
#  - 404_dance: /workspace/users/yijin/boot_env/pjt/data/reference_dances/404_dance/reference.npy
#  - basic_movement: /workspace/users/yijin/boot_env/pjt/data/reference_dances/basic_movement/reference.npy
#  - beginner_wave: /workspace/users/yijin/boot_env/pjt/data/reference_dances/beginner_wave/reference.npy
#  - cheerup_dance: /workspace/users/yijin/boot_env/pjt/data/reference_dances/cheerup_dance/reference.npy
#  - freestyle_free: /workspace/users/yijin/boot_env/pjt/data/reference_dances/freestyle_free/reference.npy
#  - hiphop_move: /workspace/users/yijin/boot_env/pjt/data/reference_dances/hiphop_move/reference.npy
#  - kpop_basic: /workspace/users/yijin/boot_env/pjt/data/reference_dances/kpop_basic/reference.npy
#  - rasputin: /workspace/users/yijin/boot_env/pjt/data/reference_dances/rasputin/reference.npy
#  - shuffle_dance: /workspace/users/yijin/boot_env/pjt/data/reference_dances/shuffle_dance/reference.npy
#  - smoke: /workspace/users/yijin/boot_env/pjt/data/reference_dances/smoke/reference.npy
# output_dir = /workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings
#
# [1/240] scratch::scratch_gcn_base_infonce_e64_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': '404_dance', 'num_windows': 18}
# [2/240] scratch::scratch_gcn_base_infonce_e64_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'basic_movement', 'num_windows': 15}
# [3/240] scratch::scratch_gcn_base_infonce_e64_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [4/240] scratch::scratch_gcn_base_infonce_e64_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [5/240] scratch::scratch_gcn_base_infonce_e64_final x freestyle_free
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'freestyle_free', 'num_windows': 120}
# [6/240] scratch::scratch_gcn_base_infonce_e64_final x hiphop_move
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'hiphop_move', 'num_windows': 26}
# [7/240] scratch::scratch_gcn_base_infonce_e64_final x kpop_basic
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'kpop_basic', 'num_windows': 238}
# [8/240] scratch::scratch_gcn_base_infonce_e64_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'rasputin', 'num_windows': 104}
# [9/240] scratch::scratch_gcn_base_infonce_e64_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [10/240] scratch::scratch_gcn_base_infonce_e64_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'smoke'}
# [11/240] scratch::scratch_gcn_base_triplet_e64_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': '404_dance', 'num_windows': 18}
# [12/240] scratch::scratch_gcn_base_triplet_e64_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'basic_movement', 'num_windows': 15}
# [13/240] scratch::scratch_gcn_base_triplet_e64_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [14/240] scratch::scratch_gcn_base_triplet_e64_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [15/240] scratch::scratch_gcn_base_triplet_e64_final x freestyle_free
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'freestyle_free', 'num_windows': 120}
# [16/240] scratch::scratch_gcn_base_triplet_e64_final x hiphop_move
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'hiphop_move', 'num_windows': 26}
# [17/240] scratch::scratch_gcn_base_triplet_e64_final x kpop_basic
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'kpop_basic', 'num_windows': 238}
# [18/240] scratch::scratch_gcn_base_triplet_e64_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'rasputin', 'num_windows': 104}
# [19/240] scratch::scratch_gcn_base_triplet_e64_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [20/240] scratch::scratch_gcn_base_triplet_e64_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'smoke'}
# [21/240] scratch::scratch_gcn_small_infonce_e32_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': '404_dance', 'num_windows': 18}
# [22/240] scratch::scratch_gcn_small_infonce_e32_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'basic_movement', 'num_windows': 15}
# [23/240] scratch::scratch_gcn_small_infonce_e32_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [24/240] scratch::scratch_gcn_small_infonce_e32_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [25/240] scratch::scratch_gcn_small_infonce_e32_final x freestyle_free
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'freestyle_free', 'num_windows': 120}
# [26/240] scratch::scratch_gcn_small_infonce_e32_final x hiphop_move
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'hiphop_move', 'num_windows': 26}
# [27/240] scratch::scratch_gcn_small_infonce_e32_final x kpop_basic
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'kpop_basic', 'num_windows': 238}
# [28/240] scratch::scratch_gcn_small_infonce_e32_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'rasputin', 'num_windows': 104}
# [29/240] scratch::scratch_gcn_small_infonce_e32_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [30/240] scratch::scratch_gcn_small_infonce_e32_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'smoke'}
# [31/240] scratch::scratch_gcn_small_triplet_e32_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': '404_dance', 'num_windows': 18}
# [32/240] scratch::scratch_gcn_small_triplet_e32_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'basic_movement', 'num_windows': 15}
# [33/240] scratch::scratch_gcn_small_triplet_e32_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [34/240] scratch::scratch_gcn_small_triplet_e32_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [35/240] scratch::scratch_gcn_small_triplet_e32_final x freestyle_free
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'freestyle_free', 'num_windows': 120}
# [36/240] scratch::scratch_gcn_small_triplet_e32_final x hiphop_move
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'hiphop_move', 'num_windows': 26}
# [37/240] scratch::scratch_gcn_small_triplet_e32_final x kpop_basic
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'kpop_basic', 'num_windows': 238}
# [38/240] scratch::scratch_gcn_small_triplet_e32_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'rasputin', 'num_windows': 104}
# [39/240] scratch::scratch_gcn_small_triplet_e32_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [40/240] scratch::scratch_gcn_small_triplet_e32_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'smoke'}
# [41/240] scratch::scratch_mlp_base_infonce_e64_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': '404_dance', 'num_windows': 18}
# [42/240] scratch::scratch_mlp_base_infonce_e64_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'basic_movement', 'num_windows': 15}
# [43/240] scratch::scratch_mlp_base_infonce_e64_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [44/240] scratch::scratch_mlp_base_infonce_e64_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [45/240] scratch::scratch_mlp_base_infonce_e64_final x freestyle_free
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'freestyle_free', 'num_windows': 120}
# [46/240] scratch::scratch_mlp_base_infonce_e64_final x hiphop_move
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'hiphop_move', 'num_windows': 26}
# [47/240] scratch::scratch_mlp_base_infonce_e64_final x kpop_basic
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'kpop_basic', 'num_windows': 238}
# [48/240] scratch::scratch_mlp_base_infonce_e64_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'rasputin', 'num_windows': 104}
# [49/240] scratch::scratch_mlp_base_infonce_e64_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [50/240] scratch::scratch_mlp_base_infonce_e64_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'smoke'}
# [51/240] scratch::scratch_mlp_base_triplet_e64_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': '404_dance', 'num_windows': 18}
# [52/240] scratch::scratch_mlp_base_triplet_e64_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'basic_movement', 'num_windows': 15}
# [53/240] scratch::scratch_mlp_base_triplet_e64_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [54/240] scratch::scratch_mlp_base_triplet_e64_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [55/240] scratch::scratch_mlp_base_triplet_e64_final x freestyle_free
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'freestyle_free', 'num_windows': 120}
# [56/240] scratch::scratch_mlp_base_triplet_e64_final x hiphop_move
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'hiphop_move', 'num_windows': 26}
# [57/240] scratch::scratch_mlp_base_triplet_e64_final x kpop_basic
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'kpop_basic', 'num_windows': 238}
# [58/240] scratch::scratch_mlp_base_triplet_e64_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'rasputin', 'num_windows': 104}
# [59/240] scratch::scratch_mlp_base_triplet_e64_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [60/240] scratch::scratch_mlp_base_triplet_e64_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'smoke'}
# [61/240] scratch::scratch_mlp_small_infonce_e32_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': '404_dance', 'num_windows': 18}
# [62/240] scratch::scratch_mlp_small_infonce_e32_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'basic_movement', 'num_windows': 15}
# [63/240] scratch::scratch_mlp_small_infonce_e32_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [64/240] scratch::scratch_mlp_small_infonce_e32_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [65/240] scratch::scratch_mlp_small_infonce_e32_final x freestyle_free
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'freestyle_free', 'num_windows': 120}
# [66/240] scratch::scratch_mlp_small_infonce_e32_final x hiphop_move
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'hiphop_move', 'num_windows': 26}
# [67/240] scratch::scratch_mlp_small_infonce_e32_final x kpop_basic
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'kpop_basic', 'num_windows': 238}
# [68/240] scratch::scratch_mlp_small_infonce_e32_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'rasputin', 'num_windows': 104}
# [69/240] scratch::scratch_mlp_small_infonce_e32_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [70/240] scratch::scratch_mlp_small_infonce_e32_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'smoke'}
# [71/240] scratch::scratch_mlp_small_triplet_e32_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_mlp_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_triplet_e32_final', 'dance': '404_dance', 'num_windows': 18}
# [72/240] scratch::scratch_mlp_small_triplet_e32_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_mlp_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_triplet_e32_final', 'dance': 'basic_movement', 'num_windows': 15}
# [73/240] scratch::scratch_mlp_small_triplet_e32_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_mlp_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_triplet_e32_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [74/240] scratch::scratch_mlp_small_triplet_e32_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_mlp_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_triplet_e32_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [75/240] scratch::scratch_mlp_small_triplet_e32_final x freestyle_free
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_mlp_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_triplet_e32_final', 'dance': 'freestyle_free', 'num_windows': 120}
# [76/240] scratch::scratch_mlp_small_triplet_e32_final x hiphop_move
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_mlp_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_triplet_e32_final', 'dance': 'hiphop_move', 'num_windows': 26}
# [77/240] scratch::scratch_mlp_small_triplet_e32_final x kpop_basic
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_mlp_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_triplet_e32_final', 'dance': 'kpop_basic', 'num_windows': 238}
# [78/240] scratch::scratch_mlp_small_triplet_e32_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_mlp_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_triplet_e32_final', 'dance': 'rasputin', 'num_windows': 104}
# [79/240] scratch::scratch_mlp_small_triplet_e32_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_mlp_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_triplet_e32_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [80/240] scratch::scratch_mlp_small_triplet_e32_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_mlp_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_mlp_small_triplet_e32_final', 'dance': 'smoke'}
# [81/240] scratch::scratch_tcn_base_infonce_e64_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_infonce_e64_final', 'dance': '404_dance', 'num_windows': 18}
# [82/240] scratch::scratch_tcn_base_infonce_e64_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_infonce_e64_final', 'dance': 'basic_movement', 'num_windows': 15}
# [83/240] scratch::scratch_tcn_base_infonce_e64_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_infonce_e64_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [84/240] scratch::scratch_tcn_base_infonce_e64_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_infonce_e64_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [85/240] scratch::scratch_tcn_base_infonce_e64_final x freestyle_free
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_infonce_e64_final', 'dance': 'freestyle_free', 'num_windows': 120}
# [86/240] scratch::scratch_tcn_base_infonce_e64_final x hiphop_move
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_infonce_e64_final', 'dance': 'hiphop_move', 'num_windows': 26}
# [87/240] scratch::scratch_tcn_base_infonce_e64_final x kpop_basic
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_infonce_e64_final', 'dance': 'kpop_basic', 'num_windows': 238}
# [88/240] scratch::scratch_tcn_base_infonce_e64_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_infonce_e64_final', 'dance': 'rasputin', 'num_windows': 104}
# [89/240] scratch::scratch_tcn_base_infonce_e64_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_infonce_e64_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [90/240] scratch::scratch_tcn_base_infonce_e64_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_infonce_e64_final', 'dance': 'smoke'}
# [91/240] scratch::scratch_tcn_base_triplet_e64_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_triplet_e64_final', 'dance': '404_dance', 'num_windows': 18}
# [92/240] scratch::scratch_tcn_base_triplet_e64_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_triplet_e64_final', 'dance': 'basic_movement', 'num_windows': 15}
# [93/240] scratch::scratch_tcn_base_triplet_e64_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_triplet_e64_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [94/240] scratch::scratch_tcn_base_triplet_e64_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_triplet_e64_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [95/240] scratch::scratch_tcn_base_triplet_e64_final x freestyle_free
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_triplet_e64_final', 'dance': 'freestyle_free', 'num_windows': 120}
# [96/240] scratch::scratch_tcn_base_triplet_e64_final x hiphop_move
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_triplet_e64_final', 'dance': 'hiphop_move', 'num_windows': 26}
# [97/240] scratch::scratch_tcn_base_triplet_e64_final x kpop_basic
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_triplet_e64_final', 'dance': 'kpop_basic', 'num_windows': 238}
# [98/240] scratch::scratch_tcn_base_triplet_e64_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_triplet_e64_final', 'dance': 'rasputin', 'num_windows': 104}
# [99/240] scratch::scratch_tcn_base_triplet_e64_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_triplet_e64_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [100/240] scratch::scratch_tcn_base_triplet_e64_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_base_triplet_e64_final', 'dance': 'smoke'}
# [101/240] scratch::scratch_tcn_small_infonce_e32_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_infonce_e32_final', 'dance': '404_dance', 'num_windows': 18}
# [102/240] scratch::scratch_tcn_small_infonce_e32_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_infonce_e32_final', 'dance': 'basic_movement', 'num_windows': 15}
# [103/240] scratch::scratch_tcn_small_infonce_e32_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_infonce_e32_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [104/240] scratch::scratch_tcn_small_infonce_e32_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_infonce_e32_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [105/240] scratch::scratch_tcn_small_infonce_e32_final x freestyle_free
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_infonce_e32_final', 'dance': 'freestyle_free', 'num_windows': 120}
# [106/240] scratch::scratch_tcn_small_infonce_e32_final x hiphop_move
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_infonce_e32_final', 'dance': 'hiphop_move', 'num_windows': 26}
# [107/240] scratch::scratch_tcn_small_infonce_e32_final x kpop_basic
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_infonce_e32_final', 'dance': 'kpop_basic', 'num_windows': 238}
# [108/240] scratch::scratch_tcn_small_infonce_e32_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_infonce_e32_final', 'dance': 'rasputin', 'num_windows': 104}
# [109/240] scratch::scratch_tcn_small_infonce_e32_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_infonce_e32_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [110/240] scratch::scratch_tcn_small_infonce_e32_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_infonce_e32_final', 'dance': 'smoke'}
# [111/240] scratch::scratch_tcn_small_triplet_e32_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_triplet_e32_final', 'dance': '404_dance', 'num_windows': 18}
# [112/240] scratch::scratch_tcn_small_triplet_e32_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_triplet_e32_final', 'dance': 'basic_movement', 'num_windows': 15}
# [113/240] scratch::scratch_tcn_small_triplet_e32_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_triplet_e32_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [114/240] scratch::scratch_tcn_small_triplet_e32_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_triplet_e32_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [115/240] scratch::scratch_tcn_small_triplet_e32_final x freestyle_free
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_triplet_e32_final', 'dance': 'freestyle_free', 'num_windows': 120}
# [116/240] scratch::scratch_tcn_small_triplet_e32_final x hiphop_move
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_triplet_e32_final', 'dance': 'hiphop_move', 'num_windows': 26}
# [117/240] scratch::scratch_tcn_small_triplet_e32_final x kpop_basic
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_triplet_e32_final', 'dance': 'kpop_basic', 'num_windows': 238}
# [118/240] scratch::scratch_tcn_small_triplet_e32_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_triplet_e32_final', 'dance': 'rasputin', 'num_windows': 104}
# [119/240] scratch::scratch_tcn_small_triplet_e32_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_triplet_e32_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [120/240] scratch::scratch_tcn_small_triplet_e32_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'scratch_tcn_small_triplet_e32_final', 'dance': 'smoke'}
# [121/240] embedding::finetune_gcn_base_infonce_e64_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__embedding__finetune_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_gcn_base_infonce_e64_final', 'dance': '404_dance', 'num_windows': 18}
# [122/240] embedding::finetune_gcn_base_infonce_e64_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__embedding__finetune_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_gcn_base_infonce_e64_final', 'dance': 'basic_movement', 'num_windows': 15}
# [123/240] embedding::finetune_gcn_base_infonce_e64_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__embedding__finetune_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_gcn_base_infonce_e64_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [124/240] embedding::finetune_gcn_base_infonce_e64_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__embedding__finetune_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_gcn_base_infonce_e64_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [125/240] embedding::finetune_gcn_base_infonce_e64_final x freestyle_free
# ...
# [198/240] embedding::finetune_mlp_small_triplet_e32_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__embedding__finetune_mlp_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_mlp_small_triplet_e32_final', 'dance': 'rasputin', 'num_windows': 104}
# [199/240] embedding::finetune_mlp_small_triplet_e32_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__embedding__finetune_mlp_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_mlp_small_triplet_e32_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [200/240] embedding::finetune_mlp_small_triplet_e32_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__embedding__finetune_mlp_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_mlp_small_triplet_e32_final', 'dance': 'smoke'}
# [201/240] embedding::finetune_tcn_base_infonce_e64_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__embedding__finetune_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_infonce_e64_final', 'dance': '404_dance', 'num_windows': 18}
# [202/240] embedding::finetune_tcn_base_infonce_e64_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__embedding__finetune_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_infonce_e64_final', 'dance': 'basic_movement', 'num_windows': 15}
# [203/240] embedding::finetune_tcn_base_infonce_e64_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__embedding__finetune_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_infonce_e64_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [204/240] embedding::finetune_tcn_base_infonce_e64_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__embedding__finetune_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_infonce_e64_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [205/240] embedding::finetune_tcn_base_infonce_e64_final x freestyle_free
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__embedding__finetune_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_infonce_e64_final', 'dance': 'freestyle_free', 'num_windows': 120}
# [206/240] embedding::finetune_tcn_base_infonce_e64_final x hiphop_move
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__embedding__finetune_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_infonce_e64_final', 'dance': 'hiphop_move', 'num_windows': 26}
# [207/240] embedding::finetune_tcn_base_infonce_e64_final x kpop_basic
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__embedding__finetune_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_infonce_e64_final', 'dance': 'kpop_basic', 'num_windows': 238}
# [208/240] embedding::finetune_tcn_base_infonce_e64_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__embedding__finetune_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_infonce_e64_final', 'dance': 'rasputin', 'num_windows': 104}
# [209/240] embedding::finetune_tcn_base_infonce_e64_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__embedding__finetune_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_infonce_e64_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [210/240] embedding::finetune_tcn_base_infonce_e64_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__embedding__finetune_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_infonce_e64_final', 'dance': 'smoke'}
# [211/240] embedding::finetune_tcn_base_triplet_e64_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__embedding__finetune_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_triplet_e64_final', 'dance': '404_dance', 'num_windows': 18}
# [212/240] embedding::finetune_tcn_base_triplet_e64_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__embedding__finetune_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_triplet_e64_final', 'dance': 'basic_movement', 'num_windows': 15}
# [213/240] embedding::finetune_tcn_base_triplet_e64_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__embedding__finetune_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_triplet_e64_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [214/240] embedding::finetune_tcn_base_triplet_e64_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__embedding__finetune_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_triplet_e64_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [215/240] embedding::finetune_tcn_base_triplet_e64_final x freestyle_free
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__embedding__finetune_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_triplet_e64_final', 'dance': 'freestyle_free', 'num_windows': 120}
# [216/240] embedding::finetune_tcn_base_triplet_e64_final x hiphop_move
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__embedding__finetune_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_triplet_e64_final', 'dance': 'hiphop_move', 'num_windows': 26}
# [217/240] embedding::finetune_tcn_base_triplet_e64_final x kpop_basic
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__embedding__finetune_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_triplet_e64_final', 'dance': 'kpop_basic', 'num_windows': 238}
# [218/240] embedding::finetune_tcn_base_triplet_e64_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__embedding__finetune_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_triplet_e64_final', 'dance': 'rasputin', 'num_windows': 104}
# [219/240] embedding::finetune_tcn_base_triplet_e64_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__embedding__finetune_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_triplet_e64_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [220/240] embedding::finetune_tcn_base_triplet_e64_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__embedding__finetune_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_base_triplet_e64_final', 'dance': 'smoke'}
# [221/240] embedding::finetune_tcn_small_infonce_e32_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': '404_dance', 'num_windows': 18}
# [222/240] embedding::finetune_tcn_small_infonce_e32_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'basic_movement', 'num_windows': 15}
# [223/240] embedding::finetune_tcn_small_infonce_e32_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [224/240] embedding::finetune_tcn_small_infonce_e32_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [225/240] embedding::finetune_tcn_small_infonce_e32_final x freestyle_free
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'freestyle_free', 'num_windows': 120}
# [226/240] embedding::finetune_tcn_small_infonce_e32_final x hiphop_move
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'hiphop_move', 'num_windows': 26}
# [227/240] embedding::finetune_tcn_small_infonce_e32_final x kpop_basic
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'kpop_basic', 'num_windows': 238}
# [228/240] embedding::finetune_tcn_small_infonce_e32_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'rasputin', 'num_windows': 104}
# [229/240] embedding::finetune_tcn_small_infonce_e32_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [230/240] embedding::finetune_tcn_small_infonce_e32_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'smoke'}
# [231/240] embedding::finetune_tcn_small_triplet_e32_final x 404_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': '404_dance', 'num_windows': 18}
# [232/240] embedding::finetune_tcn_small_triplet_e32_final x basic_movement
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'basic_movement', 'num_windows': 15}
# [233/240] embedding::finetune_tcn_small_triplet_e32_final x beginner_wave
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'beginner_wave', 'num_windows': 22}
# [234/240] embedding::finetune_tcn_small_triplet_e32_final x cheerup_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'cheerup_dance', 'num_windows': 24}
# [235/240] embedding::finetune_tcn_small_triplet_e32_final x freestyle_free
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'freestyle_free', 'num_windows': 120}
# [236/240] embedding::finetune_tcn_small_triplet_e32_final x hiphop_move
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'hiphop_move', 'num_windows': 26}
# [237/240] embedding::finetune_tcn_small_triplet_e32_final x kpop_basic
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'kpop_basic', 'num_windows': 238}
# [238/240] embedding::finetune_tcn_small_triplet_e32_final x rasputin
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'rasputin', 'num_windows': 104}
# [239/240] embedding::finetune_tcn_small_triplet_e32_final x shuffle_dance
#     {'status': 'planned', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'shuffle_dance', 'num_windows': 51}
# [240/240] embedding::finetune_tcn_small_triplet_e32_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride30.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'smoke'}
#
# Done. created=0, skipped=24, planned=216
# 0

# %% [markdown]
# ## 3. Smoke run: 작은 cache 하나 실제 생성
#
# 노트북과 스크립트가 제대로 동작하는지 빠르게 확인한다. `cache_stride=30`이라 파일이 작고 금방 끝난다.

# %%
SMOKE_MODEL_KIND = 'embedding'
SMOKE_MODEL_NAME = 'embedding_tcn_e32_triplet'
SMOKE_DANCE_NAME = 'cheerup_dance'
SMOKE_CACHE_STRIDE = 30

cmd = [
    sys.executable, str(SCRIPT),
    '--model-kind', SMOKE_MODEL_KIND,
    '--model-name', SMOKE_MODEL_NAME,
    '--dance-name', SMOKE_DANCE_NAME,
    '--data-dir', str(DATA_DIR),
    '--scratch-model-dir', str(SCRATCH_MODEL_DIR),
    '--embedding-model-dir', str(EMBEDDING_MODEL_DIR),
    '--output-dir', str(CACHE_DIR),
    '--cache-stride', str(SMOKE_CACHE_STRIDE),
    '--overwrite',
]
print(' '.join(cmd))
subprocess.check_call(cmd, cwd=PROJECT_ROOT)

# %% [markdown]
# ## 4. Full run 설정
#
# 실제 서비스 최적화용 cache를 만들 때 사용하는 셀이다.
#
# 추천 시작점:
#
# ```python
# MODEL_KIND = 'embedding'
# MODEL_NAMES = ['embedding_tcn_e64_triplet']
# DANCE_NAMES = []
# CACHE_STRIDE = 1
# ```
#
# scratch까지 모두 만들려면 `MODEL_KIND = 'all'`, `MODEL_NAMES = []`로 둔다. 전체 12모델 x 5곡을 stride=1로 만들면 시간이 걸릴 수 있다.

# %%
RUN_FULL_PRECOMPUTE = True #False

MODEL_KIND = 'all'                  # 'scratch', 'embedding', 'all'
MODEL_NAMES = [] # 빈 리스트면 해당 kind의 전체 모델
DANCE_NAMES = []                          # 빈 리스트면 reference.npy가 있는 전체 dance
CACHE_STRIDE = 1                           # 서비스용 추천: 1
CACHE_DTYPE = 'float16'                    # 'float16' 또는 'float32'
OVERWRITE = True

cmd = [
    sys.executable, str(SCRIPT),
    '--model-kind', MODEL_KIND,
    '--data-dir', str(DATA_DIR),
    '--scratch-model-dir', str(SCRATCH_MODEL_DIR),
    '--embedding-model-dir', str(EMBEDDING_MODEL_DIR),
    '--output-dir', str(CACHE_DIR),
    '--cache-stride', str(CACHE_STRIDE),
    '--dtype', CACHE_DTYPE,
]
for name in MODEL_NAMES:
    cmd += ['--model-name', name]
for name in DANCE_NAMES:
    cmd += ['--dance-name', name]
if OVERWRITE:
    cmd += ['--overwrite']

print(' '.join(cmd))
if RUN_FULL_PRECOMPUTE:
    subprocess.check_call(cmd, cwd=PROJECT_ROOT)
else:
    print('RUN_FULL_PRECOMPUTE=False 이므로 실행하지 않았습니다. True로 바꾸면 cache를 생성합니다.')
# Out:
# /workspace/users/yijin/boot_env/.venv/bin/python /workspace/users/yijin/boot_env/pjt/scripts/precompute_reference_embeddings.py --model-kind all --data-dir /workspace/users/yijin/boot_env/pjt/data/reference_dances --scratch-model-dir /workspace/users/yijin/boot_env/pjt/data/models/scratch --embedding-model-dir /workspace/users/yijin/boot_env/pjt/data/models/embedding --output-dir /workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings --cache-stride 1 --dtype float16 --overwrite
# PROJECT_ROOT = /workspace/users/yijin/boot_env/pjt
# models = 24
#  - scratch::scratch_gcn_base_infonce_e64_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_gcn_base_triplet_e64_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_gcn_small_infonce_e32_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_gcn_small_triplet_e32_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_mlp_base_infonce_e64_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_mlp_base_triplet_e64_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_mlp_small_infonce_e32_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_mlp_small_triplet_e32_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_tcn_base_infonce_e64_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_tcn_base_triplet_e64_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_tcn_small_infonce_e32_final seq=30 fd=2 layout=BTJC
#  - scratch::scratch_tcn_small_triplet_e32_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_gcn_base_infonce_e64_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_gcn_base_triplet_e64_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_gcn_small_infonce_e32_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_gcn_small_triplet_e32_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_mlp_base_infonce_e64_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_mlp_base_triplet_e64_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_mlp_small_infonce_e32_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_mlp_small_triplet_e32_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_tcn_base_infonce_e64_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_tcn_base_triplet_e64_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_tcn_small_infonce_e32_final seq=30 fd=2 layout=BTJC
#  - embedding::finetune_tcn_small_triplet_e32_final seq=30 fd=2 layout=BTJC
# dances = 10
#  - 404_dance: /workspace/users/yijin/boot_env/pjt/data/reference_dances/404_dance/reference.npy
#  - basic_movement: /workspace/users/yijin/boot_env/pjt/data/reference_dances/basic_movement/reference.npy
#  - beginner_wave: /workspace/users/yijin/boot_env/pjt/data/reference_dances/beginner_wave/reference.npy
#  - cheerup_dance: /workspace/users/yijin/boot_env/pjt/data/reference_dances/cheerup_dance/reference.npy
#  - freestyle_free: /workspace/users/yijin/boot_env/pjt/data/reference_dances/freestyle_free/reference.npy
#  - hiphop_move: /workspace/users/yijin/boot_env/pjt/data/reference_dances/hiphop_move/reference.npy
#  - kpop_basic: /workspace/users/yijin/boot_env/pjt/data/reference_dances/kpop_basic/reference.npy
#  - rasputin: /workspace/users/yijin/boot_env/pjt/data/reference_dances/rasputin/reference.npy
#  - shuffle_dance: /workspace/users/yijin/boot_env/pjt/data/reference_dances/shuffle_dance/reference.npy
#  - smoke: /workspace/users/yijin/boot_env/pjt/data/reference_dances/smoke/reference.npy
# output_dir = /workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings
#
# [1/240] scratch::scratch_gcn_base_infonce_e64_final x 404_dance
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#     404_dance / scratch_gcn_base_infonce_e64_final: 500/539 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': '404_dance', 'num_windows': 539, 'embedding_dim': 64, 'elapsed_sec': 1.022}
# [2/240] scratch::scratch_gcn_base_infonce_e64_final x basic_movement
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'basic_movement', 'num_windows': 447, 'embedding_dim': 64, 'elapsed_sec': 0.846}
# [3/240] scratch::scratch_gcn_base_infonce_e64_final x beginner_wave
#     beginner_wave / scratch_gcn_base_infonce_e64_final: 500/650 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'beginner_wave', 'num_windows': 650, 'embedding_dim': 64, 'elapsed_sec': 1.23}
# [4/240] scratch::scratch_gcn_base_infonce_e64_final x cheerup_dance
#     cheerup_dance / scratch_gcn_base_infonce_e64_final: 500/695 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'cheerup_dance', 'num_windows': 695, 'embedding_dim': 64, 'elapsed_sec': 1.312}
# [5/240] scratch::scratch_gcn_base_infonce_e64_final x freestyle_free
#     freestyle_free / scratch_gcn_base_infonce_e64_final: 500/3571 windows
#     freestyle_free / scratch_gcn_base_infonce_e64_final: 1000/3571 windows
#     freestyle_free / scratch_gcn_base_infonce_e64_final: 1500/3571 windows
#     freestyle_free / scratch_gcn_base_infonce_e64_final: 2000/3571 windows
#     freestyle_free / scratch_gcn_base_infonce_e64_final: 2500/3571 windows
#     freestyle_free / scratch_gcn_base_infonce_e64_final: 3000/3571 windows
#     freestyle_free / scratch_gcn_base_infonce_e64_final: 3500/3571 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'freestyle_free', 'num_windows': 3571, 'embedding_dim': 64, 'elapsed_sec': 6.759}
# [6/240] scratch::scratch_gcn_base_infonce_e64_final x hiphop_move
#     hiphop_move / scratch_gcn_base_infonce_e64_final: 500/763 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'hiphop_move', 'num_windows': 763, 'embedding_dim': 64, 'elapsed_sec': 1.445}
# [7/240] scratch::scratch_gcn_base_infonce_e64_final x kpop_basic
#     kpop_basic / scratch_gcn_base_infonce_e64_final: 500/7135 windows
#     kpop_basic / scratch_gcn_base_infonce_e64_final: 1000/7135 windows
#     kpop_basic / scratch_gcn_base_infonce_e64_final: 1500/7135 windows
#     kpop_basic / scratch_gcn_base_infonce_e64_final: 2000/7135 windows
#     kpop_basic / scratch_gcn_base_infonce_e64_final: 2500/7135 windows
#     kpop_basic / scratch_gcn_base_infonce_e64_final: 3000/7135 windows
#     kpop_basic / scratch_gcn_base_infonce_e64_final: 3500/7135 windows
#     kpop_basic / scratch_gcn_base_infonce_e64_final: 4000/7135 windows
#     kpop_basic / scratch_gcn_base_infonce_e64_final: 4500/7135 windows
#     kpop_basic / scratch_gcn_base_infonce_e64_final: 5000/7135 windows
#     kpop_basic / scratch_gcn_base_infonce_e64_final: 5500/7135 windows
#     kpop_basic / scratch_gcn_base_infonce_e64_final: 6000/7135 windows
#     kpop_basic / scratch_gcn_base_infonce_e64_final: 6500/7135 windows
#     kpop_basic / scratch_gcn_base_infonce_e64_final: 7000/7135 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'kpop_basic', 'num_windows': 7135, 'embedding_dim': 64, 'elapsed_sec': 13.531}
# [8/240] scratch::scratch_gcn_base_infonce_e64_final x rasputin
#     rasputin / scratch_gcn_base_infonce_e64_final: 500/3118 windows
#     rasputin / scratch_gcn_base_infonce_e64_final: 1000/3118 windows
#     rasputin / scratch_gcn_base_infonce_e64_final: 1500/3118 windows
#     rasputin / scratch_gcn_base_infonce_e64_final: 2000/3118 windows
#     rasputin / scratch_gcn_base_infonce_e64_final: 2500/3118 windows
#     rasputin / scratch_gcn_base_infonce_e64_final: 3000/3118 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'rasputin', 'num_windows': 3118, 'embedding_dim': 64, 'elapsed_sec': 5.871}
# [9/240] scratch::scratch_gcn_base_infonce_e64_final x shuffle_dance
#     shuffle_dance / scratch_gcn_base_infonce_e64_final: 500/1509 windows
#     shuffle_dance / scratch_gcn_base_infonce_e64_final: 1000/1509 windows
#     shuffle_dance / scratch_gcn_base_infonce_e64_final: 1500/1509 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'shuffle_dance', 'num_windows': 1509, 'embedding_dim': 64, 'elapsed_sec': 2.854}
# [10/240] scratch::scratch_gcn_base_infonce_e64_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_infonce_e64_final', 'dance': 'smoke'}
# [11/240] scratch::scratch_gcn_base_triplet_e64_final x 404_dance
#     404_dance / scratch_gcn_base_triplet_e64_final: 500/539 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': '404_dance', 'num_windows': 539, 'embedding_dim': 64, 'elapsed_sec': 1.017}
# [12/240] scratch::scratch_gcn_base_triplet_e64_final x basic_movement
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'basic_movement', 'num_windows': 447, 'embedding_dim': 64, 'elapsed_sec': 0.845}
# [13/240] scratch::scratch_gcn_base_triplet_e64_final x beginner_wave
#     beginner_wave / scratch_gcn_base_triplet_e64_final: 500/650 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'beginner_wave', 'num_windows': 650, 'embedding_dim': 64, 'elapsed_sec': 1.228}
# [14/240] scratch::scratch_gcn_base_triplet_e64_final x cheerup_dance
#     cheerup_dance / scratch_gcn_base_triplet_e64_final: 500/695 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'cheerup_dance', 'num_windows': 695, 'embedding_dim': 64, 'elapsed_sec': 1.315}
# [15/240] scratch::scratch_gcn_base_triplet_e64_final x freestyle_free
#     freestyle_free / scratch_gcn_base_triplet_e64_final: 500/3571 windows
#     freestyle_free / scratch_gcn_base_triplet_e64_final: 1000/3571 windows
#     freestyle_free / scratch_gcn_base_triplet_e64_final: 1500/3571 windows
#     freestyle_free / scratch_gcn_base_triplet_e64_final: 2000/3571 windows
#     freestyle_free / scratch_gcn_base_triplet_e64_final: 2500/3571 windows
#     freestyle_free / scratch_gcn_base_triplet_e64_final: 3000/3571 windows
#     freestyle_free / scratch_gcn_base_triplet_e64_final: 3500/3571 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'freestyle_free', 'num_windows': 3571, 'embedding_dim': 64, 'elapsed_sec': 6.788}
# [16/240] scratch::scratch_gcn_base_triplet_e64_final x hiphop_move
#     hiphop_move / scratch_gcn_base_triplet_e64_final: 500/763 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'hiphop_move', 'num_windows': 763, 'embedding_dim': 64, 'elapsed_sec': 1.465}
# [17/240] scratch::scratch_gcn_base_triplet_e64_final x kpop_basic
#     kpop_basic / scratch_gcn_base_triplet_e64_final: 500/7135 windows
#     kpop_basic / scratch_gcn_base_triplet_e64_final: 1000/7135 windows
#     kpop_basic / scratch_gcn_base_triplet_e64_final: 1500/7135 windows
#     kpop_basic / scratch_gcn_base_triplet_e64_final: 2000/7135 windows
#     kpop_basic / scratch_gcn_base_triplet_e64_final: 2500/7135 windows
#     kpop_basic / scratch_gcn_base_triplet_e64_final: 3000/7135 windows
#     kpop_basic / scratch_gcn_base_triplet_e64_final: 3500/7135 windows
#     kpop_basic / scratch_gcn_base_triplet_e64_final: 4000/7135 windows
#     kpop_basic / scratch_gcn_base_triplet_e64_final: 4500/7135 windows
#     kpop_basic / scratch_gcn_base_triplet_e64_final: 5000/7135 windows
#     kpop_basic / scratch_gcn_base_triplet_e64_final: 5500/7135 windows
#     kpop_basic / scratch_gcn_base_triplet_e64_final: 6000/7135 windows
#     kpop_basic / scratch_gcn_base_triplet_e64_final: 6500/7135 windows
#     kpop_basic / scratch_gcn_base_triplet_e64_final: 7000/7135 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'kpop_basic', 'num_windows': 7135, 'embedding_dim': 64, 'elapsed_sec': 13.747}
# [18/240] scratch::scratch_gcn_base_triplet_e64_final x rasputin
#     rasputin / scratch_gcn_base_triplet_e64_final: 500/3118 windows
#     rasputin / scratch_gcn_base_triplet_e64_final: 1000/3118 windows
#     rasputin / scratch_gcn_base_triplet_e64_final: 1500/3118 windows
#     rasputin / scratch_gcn_base_triplet_e64_final: 2000/3118 windows
#     rasputin / scratch_gcn_base_triplet_e64_final: 2500/3118 windows
#     rasputin / scratch_gcn_base_triplet_e64_final: 3000/3118 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'rasputin', 'num_windows': 3118, 'embedding_dim': 64, 'elapsed_sec': 5.989}
# [19/240] scratch::scratch_gcn_base_triplet_e64_final x shuffle_dance
#     shuffle_dance / scratch_gcn_base_triplet_e64_final: 500/1509 windows
#     shuffle_dance / scratch_gcn_base_triplet_e64_final: 1000/1509 windows
#     shuffle_dance / scratch_gcn_base_triplet_e64_final: 1500/1509 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'shuffle_dance', 'num_windows': 1509, 'embedding_dim': 64, 'elapsed_sec': 2.914}
# [20/240] scratch::scratch_gcn_base_triplet_e64_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_base_triplet_e64_final', 'dance': 'smoke'}
# [21/240] scratch::scratch_gcn_small_infonce_e32_final x 404_dance
#     404_dance / scratch_gcn_small_infonce_e32_final: 500/539 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': '404_dance', 'num_windows': 539, 'embedding_dim': 32, 'elapsed_sec': 0.651}
# [22/240] scratch::scratch_gcn_small_infonce_e32_final x basic_movement
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'basic_movement', 'num_windows': 447, 'embedding_dim': 32, 'elapsed_sec': 0.514}
# [23/240] scratch::scratch_gcn_small_infonce_e32_final x beginner_wave
#     beginner_wave / scratch_gcn_small_infonce_e32_final: 500/650 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'beginner_wave', 'num_windows': 650, 'embedding_dim': 32, 'elapsed_sec': 0.757}
# [24/240] scratch::scratch_gcn_small_infonce_e32_final x cheerup_dance
#     cheerup_dance / scratch_gcn_small_infonce_e32_final: 500/695 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'cheerup_dance', 'num_windows': 695, 'embedding_dim': 32, 'elapsed_sec': 0.808}
# [25/240] scratch::scratch_gcn_small_infonce_e32_final x freestyle_free
#     freestyle_free / scratch_gcn_small_infonce_e32_final: 500/3571 windows
#     freestyle_free / scratch_gcn_small_infonce_e32_final: 1000/3571 windows
#     freestyle_free / scratch_gcn_small_infonce_e32_final: 1500/3571 windows
#     freestyle_free / scratch_gcn_small_infonce_e32_final: 2000/3571 windows
#     freestyle_free / scratch_gcn_small_infonce_e32_final: 2500/3571 windows
#     freestyle_free / scratch_gcn_small_infonce_e32_final: 3000/3571 windows
#     freestyle_free / scratch_gcn_small_infonce_e32_final: 3500/3571 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'freestyle_free', 'num_windows': 3571, 'embedding_dim': 32, 'elapsed_sec': 4.171}
# [26/240] scratch::scratch_gcn_small_infonce_e32_final x hiphop_move
#     hiphop_move / scratch_gcn_small_infonce_e32_final: 500/763 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'hiphop_move', 'num_windows': 763, 'embedding_dim': 32, 'elapsed_sec': 0.869}
# [27/240] scratch::scratch_gcn_small_infonce_e32_final x kpop_basic
#     kpop_basic / scratch_gcn_small_infonce_e32_final: 500/7135 windows
#     kpop_basic / scratch_gcn_small_infonce_e32_final: 1000/7135 windows
#     kpop_basic / scratch_gcn_small_infonce_e32_final: 1500/7135 windows
#     kpop_basic / scratch_gcn_small_infonce_e32_final: 2000/7135 windows
#     kpop_basic / scratch_gcn_small_infonce_e32_final: 2500/7135 windows
#     kpop_basic / scratch_gcn_small_infonce_e32_final: 3000/7135 windows
#     kpop_basic / scratch_gcn_small_infonce_e32_final: 3500/7135 windows
#     kpop_basic / scratch_gcn_small_infonce_e32_final: 4000/7135 windows
#     kpop_basic / scratch_gcn_small_infonce_e32_final: 4500/7135 windows
#     kpop_basic / scratch_gcn_small_infonce_e32_final: 5000/7135 windows
#     kpop_basic / scratch_gcn_small_infonce_e32_final: 5500/7135 windows
#     kpop_basic / scratch_gcn_small_infonce_e32_final: 6000/7135 windows
#     kpop_basic / scratch_gcn_small_infonce_e32_final: 6500/7135 windows
#     kpop_basic / scratch_gcn_small_infonce_e32_final: 7000/7135 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'kpop_basic', 'num_windows': 7135, 'embedding_dim': 32, 'elapsed_sec': 8.118}
# [28/240] scratch::scratch_gcn_small_infonce_e32_final x rasputin
#     rasputin / scratch_gcn_small_infonce_e32_final: 500/3118 windows
#     rasputin / scratch_gcn_small_infonce_e32_final: 1000/3118 windows
#     rasputin / scratch_gcn_small_infonce_e32_final: 1500/3118 windows
#     rasputin / scratch_gcn_small_infonce_e32_final: 2000/3118 windows
#     rasputin / scratch_gcn_small_infonce_e32_final: 2500/3118 windows
#     rasputin / scratch_gcn_small_infonce_e32_final: 3000/3118 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'rasputin', 'num_windows': 3118, 'embedding_dim': 32, 'elapsed_sec': 3.594}
# [29/240] scratch::scratch_gcn_small_infonce_e32_final x shuffle_dance
#     shuffle_dance / scratch_gcn_small_infonce_e32_final: 500/1509 windows
#     shuffle_dance / scratch_gcn_small_infonce_e32_final: 1000/1509 windows
#     shuffle_dance / scratch_gcn_small_infonce_e32_final: 1500/1509 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'shuffle_dance', 'num_windows': 1509, 'embedding_dim': 32, 'elapsed_sec': 1.753}
# [30/240] scratch::scratch_gcn_small_infonce_e32_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_infonce_e32_final', 'dance': 'smoke'}
# [31/240] scratch::scratch_gcn_small_triplet_e32_final x 404_dance
#     404_dance / scratch_gcn_small_triplet_e32_final: 500/539 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': '404_dance', 'num_windows': 539, 'embedding_dim': 32, 'elapsed_sec': 0.619}
# [32/240] scratch::scratch_gcn_small_triplet_e32_final x basic_movement
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'basic_movement', 'num_windows': 447, 'embedding_dim': 32, 'elapsed_sec': 0.512}
# [33/240] scratch::scratch_gcn_small_triplet_e32_final x beginner_wave
#     beginner_wave / scratch_gcn_small_triplet_e32_final: 500/650 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'beginner_wave', 'num_windows': 650, 'embedding_dim': 32, 'elapsed_sec': 0.739}
# [34/240] scratch::scratch_gcn_small_triplet_e32_final x cheerup_dance
#     cheerup_dance / scratch_gcn_small_triplet_e32_final: 500/695 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'cheerup_dance', 'num_windows': 695, 'embedding_dim': 32, 'elapsed_sec': 0.79}
# [35/240] scratch::scratch_gcn_small_triplet_e32_final x freestyle_free
#     freestyle_free / scratch_gcn_small_triplet_e32_final: 500/3571 windows
#     freestyle_free / scratch_gcn_small_triplet_e32_final: 1000/3571 windows
#     freestyle_free / scratch_gcn_small_triplet_e32_final: 1500/3571 windows
#     freestyle_free / scratch_gcn_small_triplet_e32_final: 2000/3571 windows
#     freestyle_free / scratch_gcn_small_triplet_e32_final: 2500/3571 windows
#     freestyle_free / scratch_gcn_small_triplet_e32_final: 3000/3571 windows
#     freestyle_free / scratch_gcn_small_triplet_e32_final: 3500/3571 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'freestyle_free', 'num_windows': 3571, 'embedding_dim': 32, 'elapsed_sec': 4.084}
# [36/240] scratch::scratch_gcn_small_triplet_e32_final x hiphop_move
#     hiphop_move / scratch_gcn_small_triplet_e32_final: 500/763 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'hiphop_move', 'num_windows': 763, 'embedding_dim': 32, 'elapsed_sec': 0.866}
# [37/240] scratch::scratch_gcn_small_triplet_e32_final x kpop_basic
#     kpop_basic / scratch_gcn_small_triplet_e32_final: 500/7135 windows
#     kpop_basic / scratch_gcn_small_triplet_e32_final: 1000/7135 windows
#     kpop_basic / scratch_gcn_small_triplet_e32_final: 1500/7135 windows
#     kpop_basic / scratch_gcn_small_triplet_e32_final: 2000/7135 windows
#     kpop_basic / scratch_gcn_small_triplet_e32_final: 2500/7135 windows
#     kpop_basic / scratch_gcn_small_triplet_e32_final: 3000/7135 windows
#     kpop_basic / scratch_gcn_small_triplet_e32_final: 3500/7135 windows
#     kpop_basic / scratch_gcn_small_triplet_e32_final: 4000/7135 windows
#     kpop_basic / scratch_gcn_small_triplet_e32_final: 4500/7135 windows
#     kpop_basic / scratch_gcn_small_triplet_e32_final: 5000/7135 windows
#     kpop_basic / scratch_gcn_small_triplet_e32_final: 5500/7135 windows
#     kpop_basic / scratch_gcn_small_triplet_e32_final: 6000/7135 windows
#     kpop_basic / scratch_gcn_small_triplet_e32_final: 6500/7135 windows
#     kpop_basic / scratch_gcn_small_triplet_e32_final: 7000/7135 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'kpop_basic', 'num_windows': 7135, 'embedding_dim': 32, 'elapsed_sec': 8.105}
# [38/240] scratch::scratch_gcn_small_triplet_e32_final x rasputin
#     rasputin / scratch_gcn_small_triplet_e32_final: 500/3118 windows
#     rasputin / scratch_gcn_small_triplet_e32_final: 1000/3118 windows
#     rasputin / scratch_gcn_small_triplet_e32_final: 1500/3118 windows
#     rasputin / scratch_gcn_small_triplet_e32_final: 2000/3118 windows
#     rasputin / scratch_gcn_small_triplet_e32_final: 2500/3118 windows
#     rasputin / scratch_gcn_small_triplet_e32_final: 3000/3118 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'rasputin', 'num_windows': 3118, 'embedding_dim': 32, 'elapsed_sec': 3.584}
# [39/240] scratch::scratch_gcn_small_triplet_e32_final x shuffle_dance
#     shuffle_dance / scratch_gcn_small_triplet_e32_final: 500/1509 windows
#     shuffle_dance / scratch_gcn_small_triplet_e32_final: 1000/1509 windows
#     shuffle_dance / scratch_gcn_small_triplet_e32_final: 1500/1509 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'shuffle_dance', 'num_windows': 1509, 'embedding_dim': 32, 'elapsed_sec': 1.725}
# [40/240] scratch::scratch_gcn_small_triplet_e32_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_gcn_small_triplet_e32_final', 'dance': 'smoke'}
# [41/240] scratch::scratch_mlp_base_infonce_e64_final x 404_dance
#     404_dance / scratch_mlp_base_infonce_e64_final: 500/539 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': '404_dance', 'num_windows': 539, 'embedding_dim': 64, 'elapsed_sec': 0.497}
# [42/240] scratch::scratch_mlp_base_infonce_e64_final x basic_movement
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'basic_movement', 'num_windows': 447, 'embedding_dim': 64, 'elapsed_sec': 0.411}
# [43/240] scratch::scratch_mlp_base_infonce_e64_final x beginner_wave
#     beginner_wave / scratch_mlp_base_infonce_e64_final: 500/650 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'beginner_wave', 'num_windows': 650, 'embedding_dim': 64, 'elapsed_sec': 0.601}
# [44/240] scratch::scratch_mlp_base_infonce_e64_final x cheerup_dance
#     cheerup_dance / scratch_mlp_base_infonce_e64_final: 500/695 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'cheerup_dance', 'num_windows': 695, 'embedding_dim': 64, 'elapsed_sec': 0.646}
# [45/240] scratch::scratch_mlp_base_infonce_e64_final x freestyle_free
#     freestyle_free / scratch_mlp_base_infonce_e64_final: 500/3571 windows
#     freestyle_free / scratch_mlp_base_infonce_e64_final: 1000/3571 windows
#     freestyle_free / scratch_mlp_base_infonce_e64_final: 1500/3571 windows
#     freestyle_free / scratch_mlp_base_infonce_e64_final: 2000/3571 windows
#     freestyle_free / scratch_mlp_base_infonce_e64_final: 2500/3571 windows
#     freestyle_free / scratch_mlp_base_infonce_e64_final: 3000/3571 windows
#     freestyle_free / scratch_mlp_base_infonce_e64_final: 3500/3571 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'freestyle_free', 'num_windows': 3571, 'embedding_dim': 64, 'elapsed_sec': 3.279}
# [46/240] scratch::scratch_mlp_base_infonce_e64_final x hiphop_move
#     hiphop_move / scratch_mlp_base_infonce_e64_final: 500/763 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'hiphop_move', 'num_windows': 763, 'embedding_dim': 64, 'elapsed_sec': 0.697}
# [47/240] scratch::scratch_mlp_base_infonce_e64_final x kpop_basic
#     kpop_basic / scratch_mlp_base_infonce_e64_final: 500/7135 windows
#     kpop_basic / scratch_mlp_base_infonce_e64_final: 1000/7135 windows
#     kpop_basic / scratch_mlp_base_infonce_e64_final: 1500/7135 windows
#     kpop_basic / scratch_mlp_base_infonce_e64_final: 2000/7135 windows
#     kpop_basic / scratch_mlp_base_infonce_e64_final: 2500/7135 windows
#     kpop_basic / scratch_mlp_base_infonce_e64_final: 3000/7135 windows
#     kpop_basic / scratch_mlp_base_infonce_e64_final: 3500/7135 windows
#     kpop_basic / scratch_mlp_base_infonce_e64_final: 4000/7135 windows
#     kpop_basic / scratch_mlp_base_infonce_e64_final: 4500/7135 windows
#     kpop_basic / scratch_mlp_base_infonce_e64_final: 5000/7135 windows
#     kpop_basic / scratch_mlp_base_infonce_e64_final: 5500/7135 windows
#     kpop_basic / scratch_mlp_base_infonce_e64_final: 6000/7135 windows
#     kpop_basic / scratch_mlp_base_infonce_e64_final: 6500/7135 windows
#     kpop_basic / scratch_mlp_base_infonce_e64_final: 7000/7135 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'kpop_basic', 'num_windows': 7135, 'embedding_dim': 64, 'elapsed_sec': 6.595}
# [48/240] scratch::scratch_mlp_base_infonce_e64_final x rasputin
#     rasputin / scratch_mlp_base_infonce_e64_final: 500/3118 windows
#     rasputin / scratch_mlp_base_infonce_e64_final: 1000/3118 windows
#     rasputin / scratch_mlp_base_infonce_e64_final: 1500/3118 windows
#     rasputin / scratch_mlp_base_infonce_e64_final: 2000/3118 windows
#     rasputin / scratch_mlp_base_infonce_e64_final: 2500/3118 windows
#     rasputin / scratch_mlp_base_infonce_e64_final: 3000/3118 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'rasputin', 'num_windows': 3118, 'embedding_dim': 64, 'elapsed_sec': 2.907}
# [49/240] scratch::scratch_mlp_base_infonce_e64_final x shuffle_dance
#     shuffle_dance / scratch_mlp_base_infonce_e64_final: 500/1509 windows
#     shuffle_dance / scratch_mlp_base_infonce_e64_final: 1000/1509 windows
#     shuffle_dance / scratch_mlp_base_infonce_e64_final: 1500/1509 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'shuffle_dance', 'num_windows': 1509, 'embedding_dim': 64, 'elapsed_sec': 1.428}
# [50/240] scratch::scratch_mlp_base_infonce_e64_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_infonce_e64_final', 'dance': 'smoke'}
# [51/240] scratch::scratch_mlp_base_triplet_e64_final x 404_dance
#     404_dance / scratch_mlp_base_triplet_e64_final: 500/539 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': '404_dance', 'num_windows': 539, 'embedding_dim': 64, 'elapsed_sec': 0.502}
# [52/240] scratch::scratch_mlp_base_triplet_e64_final x basic_movement
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'basic_movement', 'num_windows': 447, 'embedding_dim': 64, 'elapsed_sec': 0.426}
# [53/240] scratch::scratch_mlp_base_triplet_e64_final x beginner_wave
#     beginner_wave / scratch_mlp_base_triplet_e64_final: 500/650 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'beginner_wave', 'num_windows': 650, 'embedding_dim': 64, 'elapsed_sec': 0.598}
# [54/240] scratch::scratch_mlp_base_triplet_e64_final x cheerup_dance
#     cheerup_dance / scratch_mlp_base_triplet_e64_final: 500/695 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'cheerup_dance', 'num_windows': 695, 'embedding_dim': 64, 'elapsed_sec': 0.642}
# [55/240] scratch::scratch_mlp_base_triplet_e64_final x freestyle_free
#     freestyle_free / scratch_mlp_base_triplet_e64_final: 500/3571 windows
#     freestyle_free / scratch_mlp_base_triplet_e64_final: 1000/3571 windows
#     freestyle_free / scratch_mlp_base_triplet_e64_final: 1500/3571 windows
#     freestyle_free / scratch_mlp_base_triplet_e64_final: 2000/3571 windows
#     freestyle_free / scratch_mlp_base_triplet_e64_final: 2500/3571 windows
#     freestyle_free / scratch_mlp_base_triplet_e64_final: 3000/3571 windows
#     freestyle_free / scratch_mlp_base_triplet_e64_final: 3500/3571 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'freestyle_free', 'num_windows': 3571, 'embedding_dim': 64, 'elapsed_sec': 3.362}
# [56/240] scratch::scratch_mlp_base_triplet_e64_final x hiphop_move
#     hiphop_move / scratch_mlp_base_triplet_e64_final: 500/763 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'hiphop_move', 'num_windows': 763, 'embedding_dim': 64, 'elapsed_sec': 0.717}
# [57/240] scratch::scratch_mlp_base_triplet_e64_final x kpop_basic
#     kpop_basic / scratch_mlp_base_triplet_e64_final: 500/7135 windows
#     kpop_basic / scratch_mlp_base_triplet_e64_final: 1000/7135 windows
#     kpop_basic / scratch_mlp_base_triplet_e64_final: 1500/7135 windows
#     kpop_basic / scratch_mlp_base_triplet_e64_final: 2000/7135 windows
#     kpop_basic / scratch_mlp_base_triplet_e64_final: 2500/7135 windows
#     kpop_basic / scratch_mlp_base_triplet_e64_final: 3000/7135 windows
#     kpop_basic / scratch_mlp_base_triplet_e64_final: 3500/7135 windows
#     kpop_basic / scratch_mlp_base_triplet_e64_final: 4000/7135 windows
#     kpop_basic / scratch_mlp_base_triplet_e64_final: 4500/7135 windows
#     kpop_basic / scratch_mlp_base_triplet_e64_final: 5000/7135 windows
#     kpop_basic / scratch_mlp_base_triplet_e64_final: 5500/7135 windows
#     kpop_basic / scratch_mlp_base_triplet_e64_final: 6000/7135 windows
#     kpop_basic / scratch_mlp_base_triplet_e64_final: 6500/7135 windows
#     kpop_basic / scratch_mlp_base_triplet_e64_final: 7000/7135 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'kpop_basic', 'num_windows': 7135, 'embedding_dim': 64, 'elapsed_sec': 6.714}
# [58/240] scratch::scratch_mlp_base_triplet_e64_final x rasputin
#     rasputin / scratch_mlp_base_triplet_e64_final: 500/3118 windows
#     rasputin / scratch_mlp_base_triplet_e64_final: 1000/3118 windows
#     rasputin / scratch_mlp_base_triplet_e64_final: 1500/3118 windows
#     rasputin / scratch_mlp_base_triplet_e64_final: 2000/3118 windows
#     rasputin / scratch_mlp_base_triplet_e64_final: 2500/3118 windows
#     rasputin / scratch_mlp_base_triplet_e64_final: 3000/3118 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'rasputin', 'num_windows': 3118, 'embedding_dim': 64, 'elapsed_sec': 2.951}
# [59/240] scratch::scratch_mlp_base_triplet_e64_final x shuffle_dance
#     shuffle_dance / scratch_mlp_base_triplet_e64_final: 500/1509 windows
#     shuffle_dance / scratch_mlp_base_triplet_e64_final: 1000/1509 windows
#     shuffle_dance / scratch_mlp_base_triplet_e64_final: 1500/1509 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'shuffle_dance', 'num_windows': 1509, 'embedding_dim': 64, 'elapsed_sec': 1.418}
# [60/240] scratch::scratch_mlp_base_triplet_e64_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_base_triplet_e64_final', 'dance': 'smoke'}
# [61/240] scratch::scratch_mlp_small_infonce_e32_final x 404_dance
#     404_dance / scratch_mlp_small_infonce_e32_final: 500/539 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': '404_dance', 'num_windows': 539, 'embedding_dim': 32, 'elapsed_sec': 0.492}
# [62/240] scratch::scratch_mlp_small_infonce_e32_final x basic_movement
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'basic_movement', 'num_windows': 447, 'embedding_dim': 32, 'elapsed_sec': 0.421}
# [63/240] scratch::scratch_mlp_small_infonce_e32_final x beginner_wave
#     beginner_wave / scratch_mlp_small_infonce_e32_final: 500/650 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'beginner_wave', 'num_windows': 650, 'embedding_dim': 32, 'elapsed_sec': 0.618}
# [64/240] scratch::scratch_mlp_small_infonce_e32_final x cheerup_dance
#     cheerup_dance / scratch_mlp_small_infonce_e32_final: 500/695 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'cheerup_dance', 'num_windows': 695, 'embedding_dim': 32, 'elapsed_sec': 0.658}
# [65/240] scratch::scratch_mlp_small_infonce_e32_final x freestyle_free
#     freestyle_free / scratch_mlp_small_infonce_e32_final: 500/3571 windows
#     freestyle_free / scratch_mlp_small_infonce_e32_final: 1000/3571 windows
#     freestyle_free / scratch_mlp_small_infonce_e32_final: 1500/3571 windows
#     freestyle_free / scratch_mlp_small_infonce_e32_final: 2000/3571 windows
#     freestyle_free / scratch_mlp_small_infonce_e32_final: 2500/3571 windows
#     freestyle_free / scratch_mlp_small_infonce_e32_final: 3000/3571 windows
#     freestyle_free / scratch_mlp_small_infonce_e32_final: 3500/3571 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'freestyle_free', 'num_windows': 3571, 'embedding_dim': 32, 'elapsed_sec': 3.334}
# [66/240] scratch::scratch_mlp_small_infonce_e32_final x hiphop_move
#     hiphop_move / scratch_mlp_small_infonce_e32_final: 500/763 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'hiphop_move', 'num_windows': 763, 'embedding_dim': 32, 'elapsed_sec': 0.707}
# [67/240] scratch::scratch_mlp_small_infonce_e32_final x kpop_basic
#     kpop_basic / scratch_mlp_small_infonce_e32_final: 500/7135 windows
#     kpop_basic / scratch_mlp_small_infonce_e32_final: 1000/7135 windows
#     kpop_basic / scratch_mlp_small_infonce_e32_final: 1500/7135 windows
#     kpop_basic / scratch_mlp_small_infonce_e32_final: 2000/7135 windows
#     kpop_basic / scratch_mlp_small_infonce_e32_final: 2500/7135 windows
#     kpop_basic / scratch_mlp_small_infonce_e32_final: 3000/7135 windows
#     kpop_basic / scratch_mlp_small_infonce_e32_final: 3500/7135 windows
#     kpop_basic / scratch_mlp_small_infonce_e32_final: 4000/7135 windows
#     kpop_basic / scratch_mlp_small_infonce_e32_final: 4500/7135 windows
#     kpop_basic / scratch_mlp_small_infonce_e32_final: 5000/7135 windows
#     kpop_basic / scratch_mlp_small_infonce_e32_final: 5500/7135 windows
#     kpop_basic / scratch_mlp_small_infonce_e32_final: 6000/7135 windows
#     kpop_basic / scratch_mlp_small_infonce_e32_final: 6500/7135 windows
#     kpop_basic / scratch_mlp_small_infonce_e32_final: 7000/7135 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'kpop_basic', 'num_windows': 7135, 'embedding_dim': 32, 'elapsed_sec': 6.662}
# [68/240] scratch::scratch_mlp_small_infonce_e32_final x rasputin
#     rasputin / scratch_mlp_small_infonce_e32_final: 500/3118 windows
#     rasputin / scratch_mlp_small_infonce_e32_final: 1000/3118 windows
#     rasputin / scratch_mlp_small_infonce_e32_final: 1500/3118 windows
#     rasputin / scratch_mlp_small_infonce_e32_final: 2000/3118 windows
#     rasputin / scratch_mlp_small_infonce_e32_final: 2500/3118 windows
#     rasputin / scratch_mlp_small_infonce_e32_final: 3000/3118 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'rasputin', 'num_windows': 3118, 'embedding_dim': 32, 'elapsed_sec': 2.863}
# [69/240] scratch::scratch_mlp_small_infonce_e32_final x shuffle_dance
#     shuffle_dance / scratch_mlp_small_infonce_e32_final: 500/1509 windows
#     shuffle_dance / scratch_mlp_small_infonce_e32_final: 1000/1509 windows
#     shuffle_dance / scratch_mlp_small_infonce_e32_final: 1500/1509 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'scratch_mlp_small_infonce_e32_final', 'dance': 'shuffle_dance', 'num_windows': 1509, 'embedding_dim': 32, 'elapsed_sec': 1.412}
# [70/240] scratch::scratch_mlp_small_infonce_e32_final x smoke
# ...
#     kpop_basic / finetune_tcn_base_triplet_e64_final: 2500/7135 windows
#     kpop_basic / finetune_tcn_base_triplet_e64_final: 3000/7135 windows
#     kpop_basic / finetune_tcn_base_triplet_e64_final: 3500/7135 windows
#     kpop_basic / finetune_tcn_base_triplet_e64_final: 4000/7135 windows
#     kpop_basic / finetune_tcn_base_triplet_e64_final: 4500/7135 windows
#     kpop_basic / finetune_tcn_base_triplet_e64_final: 5000/7135 windows
#     kpop_basic / finetune_tcn_base_triplet_e64_final: 5500/7135 windows
#     kpop_basic / finetune_tcn_base_triplet_e64_final: 6000/7135 windows
#     kpop_basic / finetune_tcn_base_triplet_e64_final: 6500/7135 windows
#     kpop_basic / finetune_tcn_base_triplet_e64_final: 7000/7135 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__embedding__finetune_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_base_triplet_e64_final', 'dance': 'kpop_basic', 'num_windows': 7135, 'embedding_dim': 64, 'elapsed_sec': 10.273}
# [218/240] embedding::finetune_tcn_base_triplet_e64_final x rasputin
#     rasputin / finetune_tcn_base_triplet_e64_final: 500/3118 windows
#     rasputin / finetune_tcn_base_triplet_e64_final: 1000/3118 windows
#     rasputin / finetune_tcn_base_triplet_e64_final: 1500/3118 windows
#     rasputin / finetune_tcn_base_triplet_e64_final: 2000/3118 windows
#     rasputin / finetune_tcn_base_triplet_e64_final: 2500/3118 windows
#     rasputin / finetune_tcn_base_triplet_e64_final: 3000/3118 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__embedding__finetune_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_base_triplet_e64_final', 'dance': 'rasputin', 'num_windows': 3118, 'embedding_dim': 64, 'elapsed_sec': 4.531}
# [219/240] embedding::finetune_tcn_base_triplet_e64_final x shuffle_dance
#     shuffle_dance / finetune_tcn_base_triplet_e64_final: 500/1509 windows
#     shuffle_dance / finetune_tcn_base_triplet_e64_final: 1000/1509 windows
#     shuffle_dance / finetune_tcn_base_triplet_e64_final: 1500/1509 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__embedding__finetune_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_base_triplet_e64_final', 'dance': 'shuffle_dance', 'num_windows': 1509, 'embedding_dim': 64, 'elapsed_sec': 2.159}
# [220/240] embedding::finetune_tcn_base_triplet_e64_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__embedding__finetune_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_base_triplet_e64_final', 'dance': 'smoke'}
# [221/240] embedding::finetune_tcn_small_infonce_e32_final x 404_dance
#     404_dance / finetune_tcn_small_infonce_e32_final: 500/539 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': '404_dance', 'num_windows': 539, 'embedding_dim': 32, 'elapsed_sec': 0.558}
# [222/240] embedding::finetune_tcn_small_infonce_e32_final x basic_movement
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'basic_movement', 'num_windows': 447, 'embedding_dim': 32, 'elapsed_sec': 0.454}
# [223/240] embedding::finetune_tcn_small_infonce_e32_final x beginner_wave
#     beginner_wave / finetune_tcn_small_infonce_e32_final: 500/650 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'beginner_wave', 'num_windows': 650, 'embedding_dim': 32, 'elapsed_sec': 0.664}
# [224/240] embedding::finetune_tcn_small_infonce_e32_final x cheerup_dance
#     cheerup_dance / finetune_tcn_small_infonce_e32_final: 500/695 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'cheerup_dance', 'num_windows': 695, 'embedding_dim': 32, 'elapsed_sec': 0.706}
# [225/240] embedding::finetune_tcn_small_infonce_e32_final x freestyle_free
#     freestyle_free / finetune_tcn_small_infonce_e32_final: 500/3571 windows
#     freestyle_free / finetune_tcn_small_infonce_e32_final: 1000/3571 windows
#     freestyle_free / finetune_tcn_small_infonce_e32_final: 1500/3571 windows
#     freestyle_free / finetune_tcn_small_infonce_e32_final: 2000/3571 windows
#     freestyle_free / finetune_tcn_small_infonce_e32_final: 2500/3571 windows
#     freestyle_free / finetune_tcn_small_infonce_e32_final: 3000/3571 windows
#     freestyle_free / finetune_tcn_small_infonce_e32_final: 3500/3571 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'freestyle_free', 'num_windows': 3571, 'embedding_dim': 32, 'elapsed_sec': 3.694}
# [226/240] embedding::finetune_tcn_small_infonce_e32_final x hiphop_move
#     hiphop_move / finetune_tcn_small_infonce_e32_final: 500/763 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'hiphop_move', 'num_windows': 763, 'embedding_dim': 32, 'elapsed_sec': 0.85}
# [227/240] embedding::finetune_tcn_small_infonce_e32_final x kpop_basic
#     kpop_basic / finetune_tcn_small_infonce_e32_final: 500/7135 windows
#     kpop_basic / finetune_tcn_small_infonce_e32_final: 1000/7135 windows
#     kpop_basic / finetune_tcn_small_infonce_e32_final: 1500/7135 windows
#     kpop_basic / finetune_tcn_small_infonce_e32_final: 2000/7135 windows
#     kpop_basic / finetune_tcn_small_infonce_e32_final: 2500/7135 windows
#     kpop_basic / finetune_tcn_small_infonce_e32_final: 3000/7135 windows
#     kpop_basic / finetune_tcn_small_infonce_e32_final: 3500/7135 windows
#     kpop_basic / finetune_tcn_small_infonce_e32_final: 4000/7135 windows
#     kpop_basic / finetune_tcn_small_infonce_e32_final: 4500/7135 windows
#     kpop_basic / finetune_tcn_small_infonce_e32_final: 5000/7135 windows
#     kpop_basic / finetune_tcn_small_infonce_e32_final: 5500/7135 windows
#     kpop_basic / finetune_tcn_small_infonce_e32_final: 6000/7135 windows
#     kpop_basic / finetune_tcn_small_infonce_e32_final: 6500/7135 windows
#     kpop_basic / finetune_tcn_small_infonce_e32_final: 7000/7135 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'kpop_basic', 'num_windows': 7135, 'embedding_dim': 32, 'elapsed_sec': 7.554}
# [228/240] embedding::finetune_tcn_small_infonce_e32_final x rasputin
#     rasputin / finetune_tcn_small_infonce_e32_final: 500/3118 windows
#     rasputin / finetune_tcn_small_infonce_e32_final: 1000/3118 windows
#     rasputin / finetune_tcn_small_infonce_e32_final: 1500/3118 windows
#     rasputin / finetune_tcn_small_infonce_e32_final: 2000/3118 windows
#     rasputin / finetune_tcn_small_infonce_e32_final: 2500/3118 windows
#     rasputin / finetune_tcn_small_infonce_e32_final: 3000/3118 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'rasputin', 'num_windows': 3118, 'embedding_dim': 32, 'elapsed_sec': 3.285}
# [229/240] embedding::finetune_tcn_small_infonce_e32_final x shuffle_dance
#     shuffle_dance / finetune_tcn_small_infonce_e32_final: 500/1509 windows
#     shuffle_dance / finetune_tcn_small_infonce_e32_final: 1000/1509 windows
#     shuffle_dance / finetune_tcn_small_infonce_e32_final: 1500/1509 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'shuffle_dance', 'num_windows': 1509, 'embedding_dim': 32, 'elapsed_sec': 1.565}
# [230/240] embedding::finetune_tcn_small_infonce_e32_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_infonce_e32_final', 'dance': 'smoke'}
# [231/240] embedding::finetune_tcn_small_triplet_e32_final x 404_dance
#     404_dance / finetune_tcn_small_triplet_e32_final: 500/539 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/404_dance__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': '404_dance', 'num_windows': 539, 'embedding_dim': 32, 'elapsed_sec': 0.554}
# [232/240] embedding::finetune_tcn_small_triplet_e32_final x basic_movement
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/basic_movement__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'basic_movement', 'num_windows': 447, 'embedding_dim': 32, 'elapsed_sec': 0.471}
# [233/240] embedding::finetune_tcn_small_triplet_e32_final x beginner_wave
#     beginner_wave / finetune_tcn_small_triplet_e32_final: 500/650 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/beginner_wave__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'beginner_wave', 'num_windows': 650, 'embedding_dim': 32, 'elapsed_sec': 0.693}
# [234/240] embedding::finetune_tcn_small_triplet_e32_final x cheerup_dance
#     cheerup_dance / finetune_tcn_small_triplet_e32_final: 500/695 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/cheerup_dance__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'cheerup_dance', 'num_windows': 695, 'embedding_dim': 32, 'elapsed_sec': 0.737}
# [235/240] embedding::finetune_tcn_small_triplet_e32_final x freestyle_free
#     freestyle_free / finetune_tcn_small_triplet_e32_final: 500/3571 windows
#     freestyle_free / finetune_tcn_small_triplet_e32_final: 1000/3571 windows
#     freestyle_free / finetune_tcn_small_triplet_e32_final: 1500/3571 windows
#     freestyle_free / finetune_tcn_small_triplet_e32_final: 2000/3571 windows
#     freestyle_free / finetune_tcn_small_triplet_e32_final: 2500/3571 windows
#     freestyle_free / finetune_tcn_small_triplet_e32_final: 3000/3571 windows
#     freestyle_free / finetune_tcn_small_triplet_e32_final: 3500/3571 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/freestyle_free__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'freestyle_free', 'num_windows': 3571, 'embedding_dim': 32, 'elapsed_sec': 3.808}
# [236/240] embedding::finetune_tcn_small_triplet_e32_final x hiphop_move
#     hiphop_move / finetune_tcn_small_triplet_e32_final: 500/763 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/hiphop_move__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'hiphop_move', 'num_windows': 763, 'embedding_dim': 32, 'elapsed_sec': 0.811}
# [237/240] embedding::finetune_tcn_small_triplet_e32_final x kpop_basic
#     kpop_basic / finetune_tcn_small_triplet_e32_final: 500/7135 windows
#     kpop_basic / finetune_tcn_small_triplet_e32_final: 1000/7135 windows
#     kpop_basic / finetune_tcn_small_triplet_e32_final: 1500/7135 windows
#     kpop_basic / finetune_tcn_small_triplet_e32_final: 2000/7135 windows
#     kpop_basic / finetune_tcn_small_triplet_e32_final: 2500/7135 windows
#     kpop_basic / finetune_tcn_small_triplet_e32_final: 3000/7135 windows
#     kpop_basic / finetune_tcn_small_triplet_e32_final: 3500/7135 windows
#     kpop_basic / finetune_tcn_small_triplet_e32_final: 4000/7135 windows
#     kpop_basic / finetune_tcn_small_triplet_e32_final: 4500/7135 windows
#     kpop_basic / finetune_tcn_small_triplet_e32_final: 5000/7135 windows
#     kpop_basic / finetune_tcn_small_triplet_e32_final: 5500/7135 windows
#     kpop_basic / finetune_tcn_small_triplet_e32_final: 6000/7135 windows
#     kpop_basic / finetune_tcn_small_triplet_e32_final: 6500/7135 windows
#     kpop_basic / finetune_tcn_small_triplet_e32_final: 7000/7135 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/kpop_basic__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'kpop_basic', 'num_windows': 7135, 'embedding_dim': 32, 'elapsed_sec': 7.44}
# [238/240] embedding::finetune_tcn_small_triplet_e32_final x rasputin
#     rasputin / finetune_tcn_small_triplet_e32_final: 500/3118 windows
#     rasputin / finetune_tcn_small_triplet_e32_final: 1000/3118 windows
#     rasputin / finetune_tcn_small_triplet_e32_final: 1500/3118 windows
#     rasputin / finetune_tcn_small_triplet_e32_final: 2000/3118 windows
#     rasputin / finetune_tcn_small_triplet_e32_final: 2500/3118 windows
#     rasputin / finetune_tcn_small_triplet_e32_final: 3000/3118 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/rasputin__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'rasputin', 'num_windows': 3118, 'embedding_dim': 32, 'elapsed_sec': 3.249}
# [239/240] embedding::finetune_tcn_small_triplet_e32_final x shuffle_dance
#     shuffle_dance / finetune_tcn_small_triplet_e32_final: 500/1509 windows
#     shuffle_dance / finetune_tcn_small_triplet_e32_final: 1000/1509 windows
#     shuffle_dance / finetune_tcn_small_triplet_e32_final: 1500/1509 windows
#     {'status': 'created', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/shuffle_dance__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'shuffle_dance', 'num_windows': 1509, 'embedding_dim': 32, 'elapsed_sec': 1.605}
# [240/240] embedding::finetune_tcn_small_triplet_e32_final x smoke
#     {'status': 'skipped', 'reason': 'too_short:1<30', 'cache_path': '/workspace/users/yijin/boot_env/pjt/data/cache/reference_embeddings/smoke__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz', 'model': 'finetune_tcn_small_triplet_e32_final', 'dance': 'smoke'}
#
# Done. created=216, skipped=24, planned=0

# %% [markdown]
# ## 5. 생성된 cache 파일 확인

# %%
cache_paths = sorted(CACHE_DIR.glob('*.npz'))
print(f'cache files: {len(cache_paths)}')
for path in cache_paths[:30]:
    with np.load(path, allow_pickle=True) as data:
        meta = json.loads(str(data['metadata']))
        emb = data['embeddings']
        end_indices = data['end_indices']
    print(f" - {path.name}")
    print(
        f"   dance={meta['dance_name']} model={meta['model_kind']}::{meta['model_name']} "
        f"windows={len(end_indices)} dim={emb.shape[1]} dtype={emb.dtype} "
        f"stride={meta['cache_stride']} size={path.stat().st_size / 1024:.1f} KiB"
    )
if len(cache_paths) > 30:
    print(f'... {len(cache_paths) - 30} more')
# Out:
# cache files: 216
#  - 404_dance__embedding__finetune_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=embedding::finetune_gcn_base_infonce_e64_final windows=539 dim=64 dtype=float16 stride=1 size=64.2 KiB
#  - 404_dance__embedding__finetune_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=embedding::finetune_gcn_base_triplet_e64_final windows=539 dim=64 dtype=float16 stride=1 size=64.2 KiB
#  - 404_dance__embedding__finetune_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=embedding::finetune_gcn_small_infonce_e32_final windows=539 dim=32 dtype=float16 stride=1 size=33.1 KiB
#  - 404_dance__embedding__finetune_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=embedding::finetune_gcn_small_triplet_e32_final windows=539 dim=32 dtype=float16 stride=1 size=33.2 KiB
#  - 404_dance__embedding__finetune_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=embedding::finetune_mlp_base_infonce_e64_final windows=539 dim=64 dtype=float16 stride=1 size=63.9 KiB
#  - 404_dance__embedding__finetune_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=embedding::finetune_mlp_base_triplet_e64_final windows=539 dim=64 dtype=float16 stride=1 size=63.8 KiB
#  - 404_dance__embedding__finetune_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=embedding::finetune_mlp_small_infonce_e32_final windows=539 dim=32 dtype=float16 stride=1 size=33.0 KiB
#  - 404_dance__embedding__finetune_mlp_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=embedding::finetune_mlp_small_triplet_e32_final windows=539 dim=32 dtype=float16 stride=1 size=32.6 KiB
#  - 404_dance__embedding__finetune_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=embedding::finetune_tcn_base_infonce_e64_final windows=539 dim=64 dtype=float16 stride=1 size=64.2 KiB
#  - 404_dance__embedding__finetune_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=embedding::finetune_tcn_base_triplet_e64_final windows=539 dim=64 dtype=float16 stride=1 size=64.1 KiB
#  - 404_dance__embedding__finetune_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=embedding::finetune_tcn_small_infonce_e32_final windows=539 dim=32 dtype=float16 stride=1 size=33.1 KiB
#  - 404_dance__embedding__finetune_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=embedding::finetune_tcn_small_triplet_e32_final windows=539 dim=32 dtype=float16 stride=1 size=33.1 KiB
#  - 404_dance__scratch__scratch_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=scratch::scratch_gcn_base_infonce_e64_final windows=539 dim=64 dtype=float16 stride=1 size=64.3 KiB
#  - 404_dance__scratch__scratch_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=scratch::scratch_gcn_base_triplet_e64_final windows=539 dim=64 dtype=float16 stride=1 size=64.0 KiB
#  - 404_dance__scratch__scratch_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=scratch::scratch_gcn_small_infonce_e32_final windows=539 dim=32 dtype=float16 stride=1 size=33.1 KiB
#  - 404_dance__scratch__scratch_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=scratch::scratch_gcn_small_triplet_e32_final windows=539 dim=32 dtype=float16 stride=1 size=33.2 KiB
#  - 404_dance__scratch__scratch_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=scratch::scratch_mlp_base_infonce_e64_final windows=539 dim=64 dtype=float16 stride=1 size=64.0 KiB
#  - 404_dance__scratch__scratch_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=scratch::scratch_mlp_base_triplet_e64_final windows=539 dim=64 dtype=float16 stride=1 size=63.8 KiB
#  - 404_dance__scratch__scratch_mlp_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=scratch::scratch_mlp_small_infonce_e32_final windows=539 dim=32 dtype=float16 stride=1 size=33.0 KiB
#  - 404_dance__scratch__scratch_mlp_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=scratch::scratch_mlp_small_triplet_e32_final windows=539 dim=32 dtype=float16 stride=1 size=33.1 KiB
#  - 404_dance__scratch__scratch_tcn_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=scratch::scratch_tcn_base_infonce_e64_final windows=539 dim=64 dtype=float16 stride=1 size=64.2 KiB
#  - 404_dance__scratch__scratch_tcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=scratch::scratch_tcn_base_triplet_e64_final windows=539 dim=64 dtype=float16 stride=1 size=64.3 KiB
#  - 404_dance__scratch__scratch_tcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=scratch::scratch_tcn_small_infonce_e32_final windows=539 dim=32 dtype=float16 stride=1 size=33.1 KiB
#  - 404_dance__scratch__scratch_tcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz
#    dance=404_dance model=scratch::scratch_tcn_small_triplet_e32_final windows=539 dim=32 dtype=float16 stride=1 size=33.2 KiB
#  - basic_movement__embedding__finetune_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz
#    dance=basic_movement model=embedding::finetune_gcn_base_infonce_e64_final windows=447 dim=64 dtype=float16 stride=1 size=53.4 KiB
#  - basic_movement__embedding__finetune_gcn_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz
#    dance=basic_movement model=embedding::finetune_gcn_base_triplet_e64_final windows=447 dim=64 dtype=float16 stride=1 size=53.4 KiB
#  - basic_movement__embedding__finetune_gcn_small_infonce_e32_final__seq30_fd2_BTJC_stride1.npz
#    dance=basic_movement model=embedding::finetune_gcn_small_infonce_e32_final windows=447 dim=32 dtype=float16 stride=1 size=27.7 KiB
#  - basic_movement__embedding__finetune_gcn_small_triplet_e32_final__seq30_fd2_BTJC_stride1.npz
#    dance=basic_movement model=embedding::finetune_gcn_small_triplet_e32_final windows=447 dim=32 dtype=float16 stride=1 size=27.7 KiB
#  - basic_movement__embedding__finetune_mlp_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz
#    dance=basic_movement model=embedding::finetune_mlp_base_infonce_e64_final windows=447 dim=64 dtype=float16 stride=1 size=53.4 KiB
#  - basic_movement__embedding__finetune_mlp_base_triplet_e64_final__seq30_fd2_BTJC_stride1.npz
#    dance=basic_movement model=embedding::finetune_mlp_base_triplet_e64_final windows=447 dim=64 dtype=float16 stride=1 size=53.0 KiB
# ... 186 more

# %% [markdown]
# ## 6. Cache 내용 검증
#
# cache에 저장된 embedding 하나를 다시 TFLite로 직접 계산해서 cosine similarity가 거의 1인지 확인한다.

# %%
from scoring.scratch_similarity import ScratchPoseSimilarity
from scoring.scratch_features import build_pose_window

cache_paths = sorted(CACHE_DIR.glob('*.npz'))
assert cache_paths, '먼저 cache를 생성하세요.'
CACHE_TO_CHECK = cache_paths[0]

with np.load(CACHE_TO_CHECK, allow_pickle=True) as data:
    meta = json.loads(str(data['metadata']))
    end_indices = data['end_indices'].astype(np.int32)
    embeddings = data['embeddings'].astype(np.float32)

print('checking:', CACHE_TO_CHECK.name)
print(json.dumps(meta, ensure_ascii=False, indent=2)[:2000])

ref = np.load(meta['reference_path'], allow_pickle=True).astype(np.float32)
if ref.ndim == 3 and ref.shape[2] == 3:
    ref = np.concatenate([ref, np.ones((*ref.shape[:2], 1), dtype=np.float32)], axis=2)
# 서비스는 cv2.flip 후 MediaPipe 추론 → 캐시도 flip 기준으로 생성됨
# 검증 시 동일하게 flip 적용해야 cosine ≈ 1.0 이 나온다
ref[:, :, 0] = 1.0 - ref[:, :, 0]

end_idx = int(end_indices[len(end_indices) // 2])
cache_pos = int(np.where(end_indices == end_idx)[0][0])
window = build_pose_window(
    ref,
    end_idx,
    int(meta['sequence_length']),
    target_joints=meta['target_joints'],
    feature_dims=int(meta['feature_dims']),
)
runner = ScratchPoseSimilarity(
    model_path=meta['model_path'],
    sequence_length=int(meta['sequence_length']),
    feature_dims=int(meta['feature_dims']),
    input_layout=meta['input_layout'],
    target_joints=meta['target_joints'],
)
emb = runner._infer_single(window).astype(np.float32)
if meta.get('l2_normalized', True):
    emb = emb / max(np.linalg.norm(emb), 1e-8)
cache_emb = embeddings[cache_pos]
cache_emb = cache_emb / max(np.linalg.norm(cache_emb), 1e-8)
cos = float(np.dot(emb, cache_emb))
print(f'end_idx={end_idx}, cache_pos={cache_pos}, cosine(recomputed, cached)={cos:.6f}')
assert cos > 0.999, 'cached embedding이 재계산 결과와 다릅니다.'
# Out:
# checking: 404_dance__embedding__finetune_gcn_base_infonce_e64_final__seq30_fd2_BTJC_stride1.npz
# {
#   "created_at": "2026-04-21T21:56:00+0900",
#   "model_kind": "embedding",
#   "model_name": "finetune_gcn_base_infonce_e64_final",
#   "model_path": "/workspace/users/yijin/boot_env/pjt/data/models/embedding/finetune_gcn_base_infonce_e64_final.tflite",
#   "model_sha256": "f9b2446089deff22560152798f8dba29998eba0c460f0c055a7e423d5f5b2a2e",
#   "model_meta_path": "/workspace/users/yijin/boot_env/pjt/data/models/embedding/finetune_gcn_base_infonce_e64_final_meta.json",
#   "dance_name": "404_dance",
#   "reference_path": "/workspace/users/yijin/boot_env/pjt/data/reference_dances/404_dance/reference.npy",
#   "reference_sha256": "04463147769a2f4d15db3e82c0e978d1c4d8658c17102536f62b9109ee7e0513",
#   "reference_frames": 568,
#   "sequence_length": 30,
#   "feature_dims": 2,
#   "input_layout": "BTJC",
#   "target_joints": [
#     11,
#     12,
#     13,
#     14,
#     15,
#     16,
#     23,
#     24,
#     25,
#     26,
#     27,
#     28
#   ],
#   "cache_stride": 1,
#   "end_index_start": 29,
#   "end_index_stop": 567,
#   "num_windows": 539,
#   "embedding_dim": 64,
#   "embedding_dtype": "float16",
#   "l2_normalized": true,
#   "elapsed_sec": 1.038
# }
# end_idx=298, cache_pos=269, cosine(recomputed, cached)=1.000000

# %% [markdown]
# ## 7. Embedding 분포 간단 확인
#
# 같은 곡 안에서 가까운 window는 cosine이 높고, 먼 window는 낮아지는지 대략 확인한다. 이 셀은 cache 파일이 제대로 만들어졌는지 보는 sanity check다.

# %%
with np.load(CACHE_TO_CHECK, allow_pickle=True) as data:
    meta = json.loads(str(data['metadata']))
    end_indices = data['end_indices'].astype(np.int32)
    embeddings = data['embeddings'].astype(np.float32)

norms = np.linalg.norm(embeddings, axis=1, keepdims=True)
embeddings_n = embeddings / np.maximum(norms, 1e-8)
anchor_idx = len(embeddings_n) // 2
sims = embeddings_n @ embeddings_n[anchor_idx]

plt.figure(figsize=(10, 3))
plt.plot(end_indices, sims)
plt.axvline(end_indices[anchor_idx], color='red', linestyle='--', label='anchor')
plt.title(f"{meta['dance_name']} / {meta['model_name']} reference embedding cosine")
plt.xlabel('reference end frame')
plt.ylabel('cosine to anchor')
plt.ylim(-1.05, 1.05)
plt.legend()
plt.grid(alpha=0.25)
plt.show()

# %% [markdown]
# ## 8. 다음 단계
#
# 이 노트북은 cache 파일을 만드는 단계까지 담당한다.
#
# 서비스 런타임 최적화를 완성하려면 다음 단계로 `ScratchPoseSimilarity`가 현재 reference sequence와 model에 맞는 `.npz` cache를 로드하고, reference 후보마다 TFLite를 다시 호출하는 대신 cache embedding을 조회하도록 연결하면 된다.
